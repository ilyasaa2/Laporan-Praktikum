# %%
Nilai_rata_rata_shafira = ((75+85)/2)
print (Nilai_rata_rata_shafira)
# Out:
# 80.0

# %%
Jumlah_nilai_Hanif_dan_Andi = (75+90+70+75)
print(Jumlah_nilai_Hanif_dan_Andi)
# Out:
# 310

# %%
data = {
    'Nama': ['Widya', 'Dhanar', 'Hikma', 'Nedia'],
    'Kalkulus 1': [85, 85, 80, 95],
    'Metode Statistika': [85, 85, 75, 80]
}

rata_rata_kalkulus = sum(data['Kalkulus 1']) / len(data['Kalkulus 1'])

rata_rata_statistika = sum(data['Metode Statistika']) / len(data['Metode Statistika'])

print(f"Rata-rata nilai Kalkulus 1: {rata_rata_kalkulus}")
print(f"Rata-rata nilai Metode Statistika: {rata_rata_statistika}")
# Out:
# Rata-rata nilai Kalkulus 1: 86.25
# Rata-rata nilai Metode Statistika: 81.25

# %%
Nilai_Rata_Rata_Matkul_Kalkulus1 = ((85+80+75+95+85+75+70+85+80)/9)
print(Nilai_Rata_Rata_Matkul_Kalkulus1)
# Out:
# 81.11111111111111

# %%
Nilai_Rata_Rata_Matkul_Metode_Statistika = ((75+90+80+80+85+90+75+85+75)/9)
print(Nilai_Rata_Rata_Matkul_Metode_Statistika)
# Out:
# 81.66666666666667

# %%
gaji_per_jam = 30000

hari_kerja = 27

jam_kerja_per_hari = 8

total_jam_kerja = jam_kerja_per_hari * hari_kerja
gaji_awal = total_jam_kerja * gaji_per_jam
hari_tidak_masuk = 3
jam_kerja_hilang = hari_tidak_masuk * jam_kerja_per_hari
gaji_setelah_potongan = gaji_awal - (jam_kerja_hilang * gaji_per_jam)
tunjangan = 0.10 * gaji_setelah_potongan
lembur_jam = 5
upah_lembur_per_jam = 10000
gaji_lembur = lembur_jam * upah_lembur_per_jam
gaji_total = gaji_setelah_potongan + tunjangan + gaji_lembur
print("Gaji setelah potongan: Rp", gaji_setelah_potongan)
print("Tunjangan: Rp", tunjangan)
print("Gaji total setelah tunjangan dan lembur: Rp", gaji_total)
# Out:
# Gaji setelah potongan: Rp 5760000
# Tunjangan: Rp 576000.0
# Gaji total setelah tunjangan dan lembur: Rp 6386000.0
